# %% [markdown]
# <b>
# <p>
# <center>
# <font size="6">
# Machine Learning 1 Project
# </font>
# </center>
# </p>
# <br>
# <p>
#
# <center>
# Worked on and submitted by:
# </center>
#
# 1. Chinmay Patil
# 2. Dilip Verma
# 3. Juhi Sinha
# 4. Somanath Joglekar

# %% [markdown]
# <b>
# <p>
# <center>
# <font size="6">
# Prediction of Stock Prices Using Deep Learning Models
# </font>
# </center>
# </p>
# <br>
# <p>
# <font size="5">
# Introduction
# </font>
# </p>
# </b>
#
# <p>
# <font size="4">
# Stock of a corporation, is all of the shares into which ownership of the corporation is divided. A single share of the stock represents fractional ownership of the corporation in proportion to the total number of shares. Stock market prediction is the act of trying to determine the future value of a company stock or other financial instrument traded on an exchange. The prediction methods are divided into two main categories: technical and fundamental analysis. The goal of our project is to train a model on stock data and then use that model to perform prediction of the prices for the following year.
# </font>
# </p>

# %%
import os
import numpy as np
import pandas as pd
from keras.optimizers import SGD
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, SimpleRNN
from sklearn.preprocessing import MinMaxScaler
from fbprophet import Prophet

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Loading data files

# %%
def create_files_dict(pth='./data/'):                                     # Creating data files
    '''
    create dictionary of files
    '''
    # pull all data files
    files = os.listdir(pth)
    print(files)
    all_data = dict()
    for file in files:

        # create key and file path
        file_key = file.split('_')[0]
        file_path = os.path.join(pth, file)

        # read the data
        data = pd.read_csv(
            file_path,
            index_col='Date',
            parse_dates=['Date']
        )

        # store data in dictionary
        all_data[file_key] = data
    return all_data

# %% [markdown]
# ## Saving the results

# %%
def plot_data(data, stock_name, pth='./figures/'):                                 # Saving the results
    '''
    plot the data
    '''
    # create train and test
    data["High"][:'2016'].plot(figsize=(16, 4), legend=True)
    data["High"]['2017':].plot(figsize=(16, 4), legend=True)

    # plot the data
    plt.legend(['Training set (Before 2017)', 'Test set (2017 and beyond)'])
    plt.title('{} stock price'.format(stock_name))
    fig_path = os.path.join(pth, stock_name + '_train_test')

    # save the data, pause, and close
    plt.savefig(fig_path)
    plt.pause(1)
    plt.close()

# %% [markdown]
# ## Data Preprocessing

# %%
def create_dl_train_test_split(all_data):
    '''
    create training/testing data and scaler object
    '''
    # create training and test set
    training_set = all_data[:'2016'].iloc[:, 1:2].values
    test_set = all_data['2017':].iloc[:, 1:2].values

    # scale the data
    sc = MinMaxScaler(feature_range=(0, 1))
    training_set_scaled = sc.fit_transform(training_set)

    # create training and test data
    X_train = []
    y_train = []
    for i in range(60, 2768):
        X_train.append(training_set_scaled[i - 60:i, 0])
        y_train.append(training_set_scaled[i, 0])
    X_train, y_train = np.array(X_train), np.array(y_train)

    # Reshaping X_train for efficient modelling
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    total_data = pd.concat(
        (all_data["High"][:'2016'], all_data["High"]['2017':]), axis=0)
    inputs = total_data[len(total_data) - len(test_set) - 60:].values
    inputs = inputs.reshape(-1, 1)
    inputs = sc.transform(inputs)

    # Preparing X_test
    X_test = []
    for i in range(60, 311):
        X_test.append(inputs[i - 60:i, 0])
    X_test = np.array(X_test)
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
    return X_train, y_train, X_test, sc

# %% [markdown]
# ## Deep Learning Models

# %% [markdown]
# ### Recurrent Neural Networks (RNN)

# %% [markdown]
# #### Single layer recurrent network with 6 Nodes

# %%
def create_single_layer_small_rnn_model(X_train, y_train, X_test, sc):
    '''
    create single layer rnn model trained on X_train and y_train
    and make predictions on the X_test data
    '''
    # create a model
    model = Sequential()
    model.add(SimpleRNN(6))
    model.add(Dense(1))
    model.compile(optimizer='rmsprop', loss='mean_squared_error')

    # fit the RNN model
    model.fit(X_train, y_train, epochs=100, batch_size=150)

    # Finalizing predictions
    scaled_preds = model.predict(X_test)
    test_preds = sc.inverse_transform(scaled_preds)
    return model, test_preds

# %% [markdown]
# #### Single layer recurrent network with 32 Nodes

# %%
def create_single_layer_rnn_model(X_train, y_train, X_test, sc):
    '''
    create single layer rnn model trained on X_train and y_train
    and make predictions on the X_test data
    '''
    # create a model
    model = Sequential()
    model.add(SimpleRNN(32))
    model.add(Dense(1))
    model.compile(optimizer='rmsprop', loss='mean_squared_error')

    # fit the RNN model
    model.fit(X_train, y_train, epochs=100, batch_size=150)

    # Finalizing predictions
    scaled_preds = model.predict(X_test)
    test_preds = sc.inverse_transform(scaled_preds)
    return model, test_preds

# %% [markdown]
# #### Simple RNN Model

# %%
def create_rnn_model(X_train, y_train, X_test, sc):
    '''
    create rnn model trained on X_train and y_train
    and make predictions on the X_test data
    '''
    # create a model
    model = Sequential()
    model.add(SimpleRNN(32, return_sequences=True))
    model.add(SimpleRNN(32, return_sequences=True))
    model.add(SimpleRNN(32, return_sequences=True))
    model.add(SimpleRNN(32))
    model.add(Dense(1))
    model.compile(optimizer='rmsprop', loss='mean_squared_error')

    # fit the RNN model
    model.fit(X_train, y_train, epochs=100, batch_size=150)

    # Finalizing predictions
    scaled_preds = model.predict(X_test)
    test_preds = sc.inverse_transform(scaled_preds)
    return model, test_preds

# %% [markdown]
# ### GRU Model

# %%
def create_GRU_model(X_train, y_train, X_test, sc):
    '''
    create GRU model trained on X_train and y_train
    and make predictions on the X_test data
    '''
    # The GRU architecture
    regressorGRU = Sequential()
    # First GRU layer with Dropout regularisation
    regressorGRU.add(GRU(units=50, return_sequences=True,
                         input_shape=(X_train.shape[1], 1), activation='tanh'))
    regressorGRU.add(GRU(units=50, return_sequences=True, activation='tanh'))
    regressorGRU.add(GRU(units=50, return_sequences=True, activation='tanh'))
    regressorGRU.add(GRU(units=50, activation='tanh'))
    regressorGRU.add(Dense(units=1))

    # Compiling the RNN
    regressorGRU.compile(
        optimizer=SGD(
            lr=0.01,
            decay=1e-7,
            momentum=0.9,
            nesterov=False),
        loss='mean_squared_error')
    # Fitting to the training set
    regressorGRU.fit(X_train, y_train, epochs=50, batch_size=150)
    GRU_predicted_stock_price = regressorGRU.predict(X_test)
    GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
    return regressorGRU, GRU_predicted_stock_price

# %% [markdown]
# #### GRU Model using Dropout

# %%
def create_GRU_with_drop_out_model(X_train, y_train, X_test, sc):
    '''
    create GRU model trained on X_train and y_train
    and make predictions on the X_test data
    '''
    # The GRU architecture
    regressorGRU = Sequential()
    # First GRU layer with Dropout regularisation
    regressorGRU.add(GRU(units=50, return_sequences=True,
                         input_shape=(X_train.shape[1], 1), activation='tanh'))
    regressorGRU.add(Dropout(0.2))
    # Second GRU layer
    regressorGRU.add(GRU(units=50, return_sequences=True, activation='tanh'))
    regressorGRU.add(Dropout(0.2))
    # Third GRU layer
    regressorGRU.add(GRU(units=50, return_sequences=True, activation='tanh'))
    regressorGRU.add(Dropout(0.2))
    # Fourth GRU layer
    regressorGRU.add(GRU(units=50, activation='tanh'))
    regressorGRU.add(Dropout(0.2))
    # The output layer
    regressorGRU.add(Dense(units=1))
    # Compiling the RNN
    regressorGRU.compile(
        optimizer=SGD(
            lr=0.01,
            decay=1e-7,
            momentum=0.9,
            nesterov=False),
        loss='mean_squared_error')
    # Fitting to the training set
    regressorGRU.fit(X_train, y_train, epochs=50, batch_size=150)
    GRU_predicted_stock_price = regressorGRU.predict(X_test)
    GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
    return regressorGRU, GRU_predicted_stock_price

# %% [markdown]
# ### Prophet Model

# %%
def create_prophet_results(all_data,
                           final_train_idx=2768,
                           pred_periods=250):
    '''
    create prophet model trained on first 2768 rows by
    default and predicts on last 250 rows
    '''
    # Pull train data
    train_data = all_data[:final_train_idx].reset_index()[['Date', 'High']]
    train_data.columns = ['ds', 'y']

    # Create and fit model
    prophet_model = Prophet()
    prophet_model.fit(train_data)

    # Provide predictions
    test_dates = prophet_model.make_future_dataframe(periods=pred_periods)
    forecast_prices = prophet_model.predict(test_dates)
    return forecast_prices

# %%
def create_prophet_daily_results(data):
    '''
    '''
    test_results = pd.DataFrame()
    for val in range(2768, 3019):

        # format training dataframe
        df = data['High'][:val].reset_index()
        df.columns = ['ds', 'y']

        # Instantiate and fit the model
        proph_model = Prophet(daily_seasonality=True)
        proph_model.fit(df)

        # create test dataframe
        test_dates = proph_model.make_future_dataframe(periods=1)

        # store test results in dataframe
        preds = proph_model.predict(test_dates).tail(1)
        test_results = test_results.append(preds)
    return test_results

# %% [markdown]
# ## Plotting the results

# %%
def plot_results(actuals,
                 stock_name,
                 small_one_layer_preds,
                 one_layer_preds,
                 yearly_prophet_preds,
                 gru_drop_preds,
                 rnn_preds,
                 gru_preds,
                 plot_pth='./figures'):
    '''
    plot the results
    '''
    plt.figure(figsize=(20, 5))
    plt.plot(yearly_prophet_preds.reset_index()[
             'yhat'].values[-250:], label='prophet yearly predictions')
    plt.plot(stock_data["High"]['2017':].values[:-1], label='actual values')
    plt.plot(small_one_layer_preds, label='Single Layer Small RNN values')
    plt.plot(one_layer_preds, label='Single Layer RNN values')
    plt.plot(gru_drop_preds, label='GRU with dropout values')
    plt.plot(rnn_preds, label='RNN values')
    plt.plot(gru_preds, label='GRU values')
    plt.title('{} Predictions from Prophet vs. Actual'.format(stock_name))
    plt.legend()
    fig_path = os.path.join(plot_pth, 'results', stock_name + '_preds')

    # save the data, pause, and close
    plt.savefig(fig_path)
    plt.pause(1)
    plt.close()

# %% [markdown]
# ## Code to run all models

# %%
if __name__ == '__main__':
    all_data = create_files_dict()
    for stock_name, stock_data in all_data.items():
        # initial plots
        plot_data(stock_data, stock_name)

        # create dl data
        X_train, y_train, X_test, sc = create_dl_train_test_split(stock_data)

        # create small single layer small rnn preds
        small_single_layer_rnn, small_one_layer_preds = create_single_layer_small_rnn_model(
            X_train, y_train, X_test, sc)

        # create single layer rnn preds
        single_layer_rnn, one_layer_preds = create_single_layer_rnn_model(
            X_train, y_train, X_test, sc)

        # rnn daily preds
        rnn_model, rnn_preds = create_rnn_model(X_train, y_train, X_test, sc)

        # gru daily preds
        gru_model, gru_preds = create_GRU_model(X_train, y_train, X_test, sc)

        # gru daily preds
        gru_drop_model, gru_drop_preds = create_GRU_with_drop_out_model(
            X_train, y_train, X_test, sc)

        # yearly preds
        yearly_preds = create_prophet_results(stock_data)

        # daily preds
        # prophet_daily_preds = create_prophet_daily_results(stock_data)

        # plot results
        plot_results(stock_data,
                     stock_name,
                     small_one_layer_preds,
                     one_layer_preds,
                     yearly_preds,
                     gru_drop_preds,
                     rnn_preds,
                     gru_preds)
# Out:
# ['JPM_2006-01-01_to_2018-01-01.csv', 'AMZN_2006-01-01_to_2018-01-01.csv', 'AAPL_2006-01-01_to_2018-01-01.csv', 'IBM_2006-01-01_to_2018-01-01.csv']
# Epoch 1/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0158
# Epoch 2/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0097
# Epoch 3/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 4/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0060
# Epoch 5/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0044
# Epoch 6/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 7/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0031
# Epoch 8/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 9/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 10/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 11/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 12/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 13/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 14/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 15/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 16/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 17/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 18/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 19/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 20/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 21/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 22/100
# 19/19 [==============================] - 0s 5ms/step - loss: 9.4058e-04
# Epoch 23/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.8531e-04
# Epoch 24/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.5195e-04
# Epoch 25/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.3958e-04
# Epoch 26/100
# 19/19 [==============================] - 0s 5ms/step - loss: 6.9648e-04
# Epoch 27/100
# 19/19 [==============================] - 0s 5ms/step - loss: 6.4141e-04
# Epoch 28/100
# 19/19 [==============================] - 0s 5ms/step - loss: 6.1069e-04
# Epoch 29/100
# 19/19 [==============================] - 0s 5ms/step - loss: 5.8157e-04
# Epoch 30/100
# 19/19 [==============================] - 0s 5ms/step - loss: 5.7370e-04
# Epoch 31/100
# 19/19 [==============================] - 0s 5ms/step - loss: 5.4815e-04
# Epoch 32/100
# 19/19 [==============================] - 0s 5ms/step - loss: 5.1712e-04
# Epoch 33/100
# 19/19 [==============================] - 0s 5ms/step - loss: 5.0168e-04
# Epoch 34/100
# 19/19 [==============================] - 0s 5ms/step - loss: 4.9487e-04
# Epoch 35/100
# 19/19 [==============================] - 0s 5ms/step - loss: 4.8545e-04
# Epoch 36/100
# 19/19 [==============================] - 0s 5ms/step - loss: 4.7158e-04
# Epoch 37/100
# 19/19 [==============================] - 0s 5ms/step - loss: 4.5165e-04
# Epoch 38/100
# 19/19 [==============================] - 0s 6ms/step - loss: 4.3134e-04
# Epoch 39/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.9375e-04
# Epoch 40/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.9304e-04
# Epoch 41/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.6540e-04
# Epoch 42/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.4022e-04
# Epoch 43/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.5500e-04
# Epoch 44/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.4905e-04
# Epoch 45/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.4544e-04
# Epoch 46/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.3037e-04
# Epoch 47/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.2913e-04
# Epoch 48/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.5008e-04
# Epoch 49/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.1054e-04
# Epoch 50/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.2537e-04
# Epoch 51/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.4877e-04
# Epoch 52/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.3767e-04
# Epoch 53/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.2104e-04
# Epoch 54/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.2604e-04
# Epoch 55/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9836e-04
# Epoch 56/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.5694e-04
# Epoch 57/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9789e-04
# Epoch 58/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.1725e-04
# Epoch 59/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0930e-04
# Epoch 60/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.4802e-04
# Epoch 61/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0878e-04
# Epoch 62/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.2049e-04
# Epoch 63/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.1300e-04
# Epoch 64/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.3093e-04
# Epoch 65/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9803e-04
# Epoch 66/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.2848e-04
# Epoch 67/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.2592e-04
# Epoch 68/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.1093e-04
# Epoch 69/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.1217e-04
# Epoch 70/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.1833e-04
# Epoch 71/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.2916e-04
# Epoch 72/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9952e-04
# Epoch 73/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0886e-04
# Epoch 74/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.1850e-04
# Epoch 75/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9165e-04
# Epoch 76/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0067e-04
# Epoch 77/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.3075e-04
# Epoch 78/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0167e-04
# Epoch 79/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9630e-04
# Epoch 80/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9931e-04
# Epoch 81/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.2119e-04
# Epoch 82/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0887e-04
# Epoch 83/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0847e-04
# Epoch 84/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9129e-04
# Epoch 85/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.4481e-04
# Epoch 86/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0217e-04
# Epoch 87/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.7661e-04
# Epoch 88/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9898e-04
# Epoch 89/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.1130e-04
# Epoch 90/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9564e-04
# Epoch 91/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9097e-04
# Epoch 92/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0053e-04
# Epoch 93/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0810e-04
# Epoch 94/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9965e-04
# Epoch 95/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0208e-04
# Epoch 96/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0664e-04
# Epoch 97/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9135e-04
# Epoch 98/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9912e-04
# Epoch 99/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9157e-04
# Epoch 100/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9347e-04
# Epoch 1/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0467
# Epoch 2/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0118
# Epoch 3/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0069
# Epoch 4/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0057
# Epoch 5/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0046
# Epoch 6/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0054
# Epoch 7/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0035
# Epoch 8/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 9/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0031
# Epoch 10/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0025
# Epoch 11/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 12/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 13/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 14/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 15/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 16/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 17/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 18/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 19/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0013
# Epoch 20/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 21/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 22/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 23/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 24/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 25/100
# 19/19 [==============================] - 0s 6ms/step - loss: 9.7340e-04
# Epoch 26/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 27/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 28/100
# 19/19 [==============================] - 0s 6ms/step - loss: 9.6997e-04
# Epoch 29/100
# 19/19 [==============================] - 0s 6ms/step - loss: 8.7316e-04
# Epoch 30/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 31/100
# 19/19 [==============================] - 0s 6ms/step - loss: 8.4750e-04
# Epoch 32/100
# 19/19 [==============================] - 0s 6ms/step - loss: 8.1088e-04
# Epoch 33/100
# 19/19 [==============================] - 0s 6ms/step - loss: 7.7438e-04
# Epoch 34/100
# 19/19 [==============================] - 0s 6ms/step - loss: 7.4394e-04
# Epoch 35/100
# 19/19 [==============================] - 0s 6ms/step - loss: 9.1124e-04
# Epoch 36/100
# 19/19 [==============================] - 0s 6ms/step - loss: 7.5305e-04
# Epoch 37/100
# 19/19 [==============================] - 0s 6ms/step - loss: 8.1514e-04
# Epoch 38/100
# 19/19 [==============================] - 0s 6ms/step - loss: 6.7431e-04
# Epoch 39/100
# 19/19 [==============================] - 0s 6ms/step - loss: 7.8490e-04
# Epoch 40/100
# 19/19 [==============================] - 0s 6ms/step - loss: 6.1510e-04
# Epoch 41/100
# 19/19 [==============================] - 0s 6ms/step - loss: 6.8317e-04
# Epoch 42/100
# 19/19 [==============================] - 0s 6ms/step - loss: 6.5866e-04
# Epoch 43/100
# 19/19 [==============================] - 0s 6ms/step - loss: 5.9888e-04
# Epoch 44/100
# 19/19 [==============================] - 0s 6ms/step - loss: 6.3912e-04
# Epoch 45/100
# 19/19 [==============================] - 0s 6ms/step - loss: 5.8360e-04
# Epoch 46/100
# 19/19 [==============================] - 0s 6ms/step - loss: 5.5071e-04
# Epoch 47/100
# 19/19 [==============================] - 0s 6ms/step - loss: 6.0122e-04
# Epoch 48/100
# 19/19 [==============================] - 0s 6ms/step - loss: 5.6692e-04
# Epoch 49/100
# 19/19 [==============================] - 0s 6ms/step - loss: 5.6678e-04
# Epoch 50/100
# 19/19 [==============================] - 0s 6ms/step - loss: 4.8524e-04
# Epoch 51/100
# 19/19 [==============================] - 0s 6ms/step - loss: 5.0989e-04
# Epoch 52/100
# 19/19 [==============================] - 0s 6ms/step - loss: 4.7948e-04
# Epoch 53/100
# 19/19 [==============================] - 0s 6ms/step - loss: 5.1392e-04
# Epoch 54/100
# 19/19 [==============================] - 0s 6ms/step - loss: 4.8604e-04
# Epoch 55/100
# 19/19 [==============================] - 0s 6ms/step - loss: 4.8453e-04
# Epoch 56/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.6069e-04
# Epoch 57/100
# 19/19 [==============================] - 0s 6ms/step - loss: 5.0145e-04
# Epoch 58/100
# 19/19 [==============================] - 0s 6ms/step - loss: 4.0148e-04
# Epoch 59/100
# 19/19 [==============================] - 0s 6ms/step - loss: 4.1259e-04
# Epoch 60/100
# 19/19 [==============================] - 0s 6ms/step - loss: 4.6183e-04
# Epoch 61/100
# 19/19 [==============================] - 0s 6ms/step - loss: 4.0163e-04
# Epoch 62/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.9784e-04
# Epoch 63/100
# 19/19 [==============================] - 0s 6ms/step - loss: 4.0912e-04
# Epoch 64/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.6240e-04
# Epoch 65/100
# 19/19 [==============================] - 0s 6ms/step - loss: 4.2216e-04
# Epoch 66/100
# 19/19 [==============================] - 0s 7ms/step - loss: 3.5469e-04
# Epoch 67/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.5400e-04
# Epoch 68/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.5256e-04
# Epoch 69/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.2318e-04
# Epoch 70/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.2659e-04
# Epoch 71/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.1899e-04
# Epoch 72/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.3557e-04
# Epoch 73/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.9682e-04
# Epoch 74/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.3201e-04
# Epoch 75/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.0943e-04
# Epoch 76/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.6842e-04
# Epoch 77/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.0057e-04
# Epoch 78/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.9056e-04
# Epoch 79/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.7582e-04
# Epoch 80/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.6830e-04
# Epoch 81/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.5917e-04
# Epoch 82/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.6217e-04
# Epoch 83/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.4045e-04
# Epoch 84/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.1078e-04
# Epoch 85/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.4543e-04
# Epoch 86/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.5388e-04
# Epoch 87/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.2890e-04
# Epoch 88/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.0159e-04
# Epoch 89/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.3802e-04
# Epoch 90/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.1489e-04
# Epoch 91/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.7120e-04
# Epoch 92/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.3241e-04
# Epoch 93/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.3750e-04
# Epoch 94/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.1676e-04
# Epoch 95/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.2196e-04
# Epoch 96/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.5088e-04
# Epoch 97/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.2157e-04
# Epoch 98/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.4346e-04
# Epoch 99/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.0160e-04
# Epoch 100/100
# 19/19 [==============================] - 0s 7ms/step - loss: 2.4014e-04
# Epoch 1/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.2065
# Epoch 2/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0330
# Epoch 3/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0283
# Epoch 4/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0281
# Epoch 5/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0233
# Epoch 6/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0190
# Epoch 7/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0169
# Epoch 8/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0174
# Epoch 9/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0164
# Epoch 10/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0127
# Epoch 11/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0130
# Epoch 12/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0101
# Epoch 13/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0111
# Epoch 14/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0103
# Epoch 15/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0112
# Epoch 16/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0070
# Epoch 17/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0077
# Epoch 18/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0078
# Epoch 19/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0078
# Epoch 20/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0070
# Epoch 21/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0070
# Epoch 22/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0075
# Epoch 23/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0058
# Epoch 24/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0058
# Epoch 25/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0056
# Epoch 26/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0055
# Epoch 27/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0059
# Epoch 28/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0043
# Epoch 29/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0058
# Epoch 30/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0048
# Epoch 31/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0048
# Epoch 32/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0039
# Epoch 33/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0055
# Epoch 34/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0038
# Epoch 35/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0043
# Epoch 36/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0041
# Epoch 37/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0039
# Epoch 38/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0038
# Epoch 39/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0037
# Epoch 40/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0040
# Epoch 41/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0035
# Epoch 42/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0031
# Epoch 43/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0033
# Epoch 44/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0032
# Epoch 45/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0033
# Epoch 46/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0033
# Epoch 47/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0031
# Epoch 48/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0029
# Epoch 49/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0035
# Epoch 50/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0027
# Epoch 51/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0029
# Epoch 52/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0030
# Epoch 53/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0026
# Epoch 54/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0030
# Epoch 55/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0035
# Epoch 56/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0018
# Epoch 57/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0022
# Epoch 58/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0026
# Epoch 59/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0025
# Epoch 60/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0023
# Epoch 61/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0042
# Epoch 62/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0025
# Epoch 63/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0021
# Epoch 64/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0024
# Epoch 65/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0024
# Epoch 66/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0023
# Epoch 67/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0022
# Epoch 68/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0021
# Epoch 69/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0022
# Epoch 70/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0024
# Epoch 71/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0023
# Epoch 72/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0019
# Epoch 73/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0019
# Epoch 74/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0023
# Epoch 75/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0020
# Epoch 76/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0020
# Epoch 77/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0019
# Epoch 78/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0021
# Epoch 79/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0017
# Epoch 80/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0016
# Epoch 81/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0022: 0s - loss:
# Epoch 82/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0017
# Epoch 83/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0018
# Epoch 84/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0019
# Epoch 85/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0022
# Epoch 86/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0012
# Epoch 87/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0017
# Epoch 88/100
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0019
# Epoch 89/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0014
# Epoch 90/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0023
# Epoch 91/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0014
# Epoch 92/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0017
# Epoch 93/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0014
# Epoch 94/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0013
# Epoch 95/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0017
# Epoch 96/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0018
# Epoch 97/100
# 19/19 [==============================] - 1s 27ms/step - loss: 9.7884e-04
# Epoch 98/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0017
# Epoch 99/100
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0016
# Epoch 100/100
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0018
# Epoch 1/50
# 19/19 [==============================] - 2s 94ms/step - loss: 0.0625
# Epoch 2/50
# 19/19 [==============================] - 2s 83ms/step - loss: 0.0186
# Epoch 3/50
# 19/19 [==============================] - 2s 89ms/step - loss: 0.0104
# Epoch 4/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0052
# Epoch 5/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0022
# Epoch 6/50
# 19/19 [==============================] - 2s 93ms/step - loss: 8.6090e-04
# Epoch 7/50
# 19/19 [==============================] - 2s 89ms/step - loss: 6.2941e-04
# Epoch 8/50
# 19/19 [==============================] - 2s 94ms/step - loss: 6.1686e-04
# Epoch 9/50
# 19/19 [==============================] - 2s 92ms/step - loss: 6.1538e-04
# Epoch 10/50
# 19/19 [==============================] - 2s 109ms/step - loss: 6.1096e-04
# Epoch 11/50
# 19/19 [==============================] - 2s 112ms/step - loss: 6.1932e-04
# Epoch 12/50
# 19/19 [==============================] - 2s 109ms/step - loss: 6.1397e-04
# Epoch 13/50
# 19/19 [==============================] - 2s 118ms/step - loss: 6.2545e-04
# Epoch 14/50
# 19/19 [==============================] - 2s 131ms/step - loss: 6.2200e-04
# Epoch 15/50
# 19/19 [==============================] - 2s 115ms/step - loss: 6.1510e-04
# Epoch 16/50
# 19/19 [==============================] - 2s 120ms/step - loss: 6.1232e-04
# Epoch 17/50
# 19/19 [==============================] - 2s 116ms/step - loss: 6.1166e-04
# Epoch 18/50
# 19/19 [==============================] - 2s 109ms/step - loss: 6.1456e-04
# Epoch 19/50
# 19/19 [==============================] - 2s 109ms/step - loss: 6.1749e-04
# Epoch 20/50
# 19/19 [==============================] - 2s 108ms/step - loss: 6.1823e-04
# Epoch 21/50
# 19/19 [==============================] - 2s 102ms/step - loss: 6.1682e-04
# Epoch 22/50
# 19/19 [==============================] - 2s 99ms/step - loss: 6.1078e-04
# Epoch 23/50
# 19/19 [==============================] - 2s 99ms/step - loss: 6.2208e-04
# Epoch 24/50
# 19/19 [==============================] - 2s 98ms/step - loss: 6.1836e-04
# Epoch 25/50
# 19/19 [==============================] - 2s 99ms/step - loss: 6.2399e-04
# Epoch 26/50
# 19/19 [==============================] - 2s 113ms/step - loss: 6.1837e-04
# Epoch 27/50
# 19/19 [==============================] - 2s 116ms/step - loss: 6.0482e-04
# Epoch 28/50
# 19/19 [==============================] - 2s 106ms/step - loss: 6.0739e-04
# Epoch 29/50
# 19/19 [==============================] - 2s 105ms/step - loss: 6.1055e-04
# Epoch 30/50
# 19/19 [==============================] - 2s 106ms/step - loss: 6.0499e-04
# Epoch 31/50
# 19/19 [==============================] - 2s 101ms/step - loss: 6.1901e-04
# Epoch 32/50
# 19/19 [==============================] - 2s 101ms/step - loss: 6.0147e-04
# Epoch 33/50
# 19/19 [==============================] - 2s 101ms/step - loss: 6.0281e-04
# Epoch 34/50
# 19/19 [==============================] - 2s 100ms/step - loss: 6.1572e-04
# Epoch 35/50
# 19/19 [==============================] - 2s 99ms/step - loss: 6.1379e-04
# Epoch 36/50
# 19/19 [==============================] - 2s 102ms/step - loss: 6.0121e-04
# Epoch 37/50
# 19/19 [==============================] - 2s 102ms/step - loss: 6.0672e-04
# Epoch 38/50
# 19/19 [==============================] - 2s 100ms/step - loss: 6.1125e-04
# Epoch 39/50
# 19/19 [==============================] - 2s 100ms/step - loss: 5.9815e-04
# Epoch 40/50
# 19/19 [==============================] - 2s 99ms/step - loss: 6.0101e-04
# Epoch 41/50
# 19/19 [==============================] - 2s 98ms/step - loss: 6.1428e-04
# Epoch 42/50
# 19/19 [==============================] - 2s 104ms/step - loss: 6.2228e-04
# Epoch 43/50
# 19/19 [==============================] - 2s 124ms/step - loss: 5.9915e-04
# Epoch 44/50
# 19/19 [==============================] - 3s 136ms/step - loss: 6.0574e-04
# Epoch 45/50
# 19/19 [==============================] - 2s 114ms/step - loss: 6.1174e-04
# Epoch 46/50
# 19/19 [==============================] - 2s 116ms/step - loss: 6.0466e-04
# Epoch 47/50
# 19/19 [==============================] - 2s 107ms/step - loss: 5.9905e-04
# Epoch 48/50
# 19/19 [==============================] - 2s 101ms/step - loss: 6.0291e-04
# Epoch 49/50
# 19/19 [==============================] - 2s 102ms/step - loss: 6.1172e-04
# Epoch 50/50
# 19/19 [==============================] - 2s 103ms/step - loss: 6.0783e-04
# Epoch 1/50
# 19/19 [==============================] - 2s 92ms/step - loss: 0.0740
# Epoch 2/50
# 19/19 [==============================] - 2s 86ms/step - loss: 0.0291
# Epoch 3/50
# 19/19 [==============================] - 2s 90ms/step - loss: 0.0189
# Epoch 4/50
# 19/19 [==============================] - 2s 95ms/step - loss: 0.0149
# Epoch 5/50
# 19/19 [==============================] - 2s 103ms/step - loss: 0.0108
# Epoch 6/50
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0068
# Epoch 7/50
# 19/19 [==============================] - 2s 114ms/step - loss: 0.0039
# Epoch 8/50
# 19/19 [==============================] - 2s 113ms/step - loss: 0.0025
# Epoch 9/50
# 19/19 [==============================] - 2s 112ms/step - loss: 0.0021
# Epoch 10/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0020
# Epoch 11/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0020
# Epoch 12/50
# 19/19 [==============================] - 2s 112ms/step - loss: 0.0018
# Epoch 13/50
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0020
# Epoch 14/50
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0019
# Epoch 15/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0018
# Epoch 16/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0019
# Epoch 17/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0017
# Epoch 18/50
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0016
# Epoch 19/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0016
# Epoch 20/50
# 19/19 [==============================] - 2s 102ms/step - loss: 0.0016
# Epoch 21/50
# 19/19 [==============================] - 2s 104ms/step - loss: 0.0015
# Epoch 22/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0015
# Epoch 23/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0015
# Epoch 24/50
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0015
# Epoch 25/50
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0015
# Epoch 26/50
# 19/19 [==============================] - 2s 114ms/step - loss: 0.0014
# Epoch 27/50
# 19/19 [==============================] - 2s 113ms/step - loss: 0.0015
# Epoch 28/50
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0015
# Epoch 29/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0014
# Epoch 30/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0014
# Epoch 31/50
# 19/19 [==============================] - 2s 102ms/step - loss: 0.0014
# Epoch 32/50
# 19/19 [==============================] - 2s 102ms/step - loss: 0.0014
# Epoch 33/50
# 19/19 [==============================] - 2s 103ms/step - loss: 0.0014
# Epoch 34/50
# 19/19 [==============================] - 2s 99ms/step - loss: 0.0014
# Epoch 35/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0014
# Epoch 36/50
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0013
# Epoch 37/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0013
# Epoch 38/50
# 19/19 [==============================] - 2s 112ms/step - loss: 0.0013
# Epoch 39/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0013
# Epoch 40/50
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0014
# Epoch 41/50
# 19/19 [==============================] - 2s 115ms/step - loss: 0.0014
# Epoch 42/50
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0014
# Epoch 43/50
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0013
# Epoch 44/50
# 19/19 [==============================] - 2s 112ms/step - loss: 0.0012
# Epoch 45/50
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0013
# Epoch 46/50
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0013
# Epoch 47/50
# 19/19 [==============================] - 2s 104ms/step - loss: 0.0012
# Epoch 48/50
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0013
# Epoch 49/50
# 19/19 [==============================] - 2s 112ms/step - loss: 0.0013
# Epoch 50/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0013
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Epoch 1/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1004
# Epoch 2/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0180
# Epoch 3/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0065
# Epoch 4/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 5/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 6/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.0480e-04
# Epoch 7/100
# 19/19 [==============================] - 0s 5ms/step - loss: 6.2542e-04
# Epoch 8/100
# 19/19 [==============================] - 0s 5ms/step - loss: 5.6780e-04
# Epoch 9/100
# 19/19 [==============================] - 0s 5ms/step - loss: 4.7874e-04
# Epoch 10/100
# 19/19 [==============================] - 0s 5ms/step - loss: 4.3132e-04
# Epoch 11/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.7247e-04
# Epoch 12/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.5606e-04
# Epoch 13/100
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0629e-04
# Epoch 14/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.8124e-04
# Epoch 15/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.6889e-04
# Epoch 16/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.3824e-04
# Epoch 17/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.1974e-04
# Epoch 18/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.2116e-04
# Epoch 19/100
# 19/19 [==============================] - 0s 5ms/step - loss: 2.0282e-04
# Epoch 20/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.8490e-04
# Epoch 21/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.8106e-04
# Epoch 22/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.7439e-04
# Epoch 23/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.6867e-04
# Epoch 24/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.6773e-04
# Epoch 25/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.5928e-04
# Epoch 26/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.4378e-04
# Epoch 27/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.5914e-04
# Epoch 28/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.4168e-04
# Epoch 29/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3831e-04
# Epoch 30/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3769e-04
# Epoch 31/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3937e-04
# Epoch 32/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2775e-04
# Epoch 33/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2754e-04
# Epoch 34/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3037e-04
# Epoch 35/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1770e-04
# Epoch 36/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2624e-04
# Epoch 37/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1458e-04
# Epoch 38/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1589e-04
# Epoch 39/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1497e-04
# Epoch 40/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1495e-04
# Epoch 41/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0223e-04
# Epoch 42/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1698e-04
# Epoch 43/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0503e-04
# Epoch 44/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0510e-04
# Epoch 45/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0565e-04
# Epoch 46/100
# 19/19 [==============================] - 0s 5ms/step - loss: 9.8617e-05
# Epoch 47/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0639e-04
# Epoch 48/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0025e-04
# Epoch 49/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0782e-04
# Epoch 50/100
# 19/19 [==============================] - 0s 5ms/step - loss: 9.7399e-05
# Epoch 51/100
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0913e-04
# Epoch 52/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.9465e-05
# Epoch 53/100
# 19/19 [==============================] - 0s 5ms/step - loss: 9.6856e-05
# Epoch 54/100
# 19/19 [==============================] - 0s 5ms/step - loss: 9.4482e-05
# Epoch 55/100
# 19/19 [==============================] - 0s 5ms/step - loss: 9.4843e-05
# Epoch 56/100
# 19/19 [==============================] - 0s 5ms/step - loss: 9.5983e-05
# Epoch 57/100
# 19/19 [==============================] - 0s 5ms/step - loss: 9.2854e-05
# Epoch 58/100
# 19/19 [==============================] - 0s 5ms/step - loss: 9.2617e-05
# Epoch 59/100
# 19/19 [==============================] - 0s 5ms/step - loss: 9.9729e-05
# Epoch 60/100
# 19/19 [==============================] - 0s 5ms/step - loss: 9.1431e-05
# Epoch 61/100
# 19/19 [==============================] - 0s 5ms/step - loss: 9.1785e-05
# Epoch 62/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.6430e-05
# Epoch 63/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.6561e-05
# Epoch 64/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.6187e-05
# Epoch 65/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.8281e-05
# Epoch 66/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.8817e-05
# Epoch 67/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.6625e-05
# Epoch 68/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.8972e-05
# Epoch 69/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.4633e-05
# Epoch 70/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.3874e-05
# Epoch 71/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.9485e-05
# Epoch 72/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.5060e-05
# Epoch 73/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.1569e-05
# Epoch 74/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.9429e-05
# Epoch 75/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.4078e-05
# Epoch 76/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.6904e-05
# Epoch 77/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.1164e-05
# Epoch 78/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.1623e-05
# Epoch 79/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.1591e-05
# Epoch 80/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.7613e-05
# Epoch 81/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.5228e-05
# Epoch 82/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.2716e-05
# Epoch 83/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.4648e-05
# Epoch 84/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.5860e-05
# Epoch 85/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.2133e-05
# Epoch 86/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.5107e-05
# Epoch 87/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.4068e-05
# Epoch 88/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.3356e-05
# Epoch 89/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.6118e-05
# Epoch 90/100
# 19/19 [==============================] - 0s 5ms/step - loss: 8.0219e-05
# Epoch 91/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.7595e-05
# Epoch 92/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.2976e-05
# Epoch 93/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.2284e-05
# Epoch 94/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.6567e-05
# Epoch 95/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.3551e-05
# Epoch 96/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.8940e-05
# Epoch 97/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.1806e-05
# Epoch 98/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.2303e-05
# Epoch 99/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.6571e-05
# Epoch 100/100
# 19/19 [==============================] - 0s 5ms/step - loss: 7.3625e-05
# Epoch 1/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0549
# Epoch 2/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 3/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 4/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 5/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 6/100
# 19/19 [==============================] - 0s 6ms/step - loss: 9.7270e-04
# Epoch 7/100
# 19/19 [==============================] - 0s 6ms/step - loss: 7.5508e-04
# Epoch 8/100
# 19/19 [==============================] - 0s 6ms/step - loss: 5.4898e-04
# Epoch 9/100
# 19/19 [==============================] - 0s 6ms/step - loss: 6.9900e-04
# Epoch 10/100
# 19/19 [==============================] - 0s 6ms/step - loss: 5.3469e-04
# Epoch 11/100
# 19/19 [==============================] - 0s 6ms/step - loss: 4.3119e-04
# Epoch 12/100
# 19/19 [==============================] - 0s 6ms/step - loss: 5.0554e-04
# Epoch 13/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.8297e-04
# Epoch 14/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.9327e-04
# Epoch 15/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.2173e-04
# Epoch 16/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.3255e-04
# Epoch 17/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.8925e-04
# Epoch 18/100
# 19/19 [==============================] - 0s 6ms/step - loss: 3.0166e-04
# Epoch 19/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.8804e-04
# Epoch 20/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.7759e-04
# Epoch 21/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.5851e-04
# Epoch 22/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.4614e-04
# Epoch 23/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.2129e-04
# Epoch 24/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.5454e-04
# Epoch 25/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.0471e-04
# Epoch 26/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.9567e-04
# Epoch 27/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.9186e-04
# Epoch 28/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.2607e-04
# Epoch 29/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.8449e-04
# Epoch 30/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.7513e-04
# Epoch 31/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.8370e-04
# Epoch 32/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5659e-04
# Epoch 33/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.9027e-04
# Epoch 34/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.9029e-04
# Epoch 35/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6004e-04
# Epoch 36/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5083e-04
# Epoch 37/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6625e-04
# Epoch 38/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4195e-04
# Epoch 39/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6017e-04
# Epoch 40/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5326e-04
# Epoch 41/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3488e-04
# Epoch 42/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2208e-04
# Epoch 43/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6017e-04
# Epoch 44/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2989e-04
# Epoch 45/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4678e-04
# Epoch 46/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5257e-04
# Epoch 47/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1809e-04
# Epoch 48/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3267e-04
# Epoch 49/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3048e-04
# Epoch 50/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2194e-04
# Epoch 51/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0060e-04
# Epoch 52/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4791e-04
# Epoch 53/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2715e-04
# Epoch 54/100
# 19/19 [==============================] - 0s 6ms/step - loss: 9.7882e-05
# Epoch 55/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2392e-04
# Epoch 56/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1051e-04
# Epoch 57/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2665e-04
# Epoch 58/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1932e-04
# Epoch 59/100
# 19/19 [==============================] - 0s 6ms/step - loss: 9.5363e-05
# Epoch 60/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0897e-04
# Epoch 61/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2320e-04
# Epoch 62/100
# 19/19 [==============================] - 0s 6ms/step - loss: 9.3785e-05
# Epoch 63/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0446e-04
# Epoch 64/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0783e-04
# Epoch 65/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1596e-04
# Epoch 66/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0025e-04
# Epoch 67/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0407e-04
# Epoch 68/100
# 19/19 [==============================] - 0s 6ms/step - loss: 9.3804e-05
# Epoch 69/100
# 19/19 [==============================] - 0s 6ms/step - loss: 8.5426e-05
# Epoch 70/100
# ...
# Epoch 9/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0122
# Epoch 10/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0121
# Epoch 11/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0137
# Epoch 12/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0093
# Epoch 13/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0084
# Epoch 14/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0100
# Epoch 15/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0092
# Epoch 16/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0073
# Epoch 17/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0076
# Epoch 18/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0104
# Epoch 19/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0065
# Epoch 20/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0065
# Epoch 21/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0076
# Epoch 22/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0062
# Epoch 23/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0063
# Epoch 24/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0068
# Epoch 25/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0069
# Epoch 26/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0061
# Epoch 27/100
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0047
# Epoch 28/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0056
# Epoch 29/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0058
# Epoch 30/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0056
# Epoch 31/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0059
# Epoch 32/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0070
# Epoch 33/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0047
# Epoch 34/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0047
# Epoch 35/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0037
# Epoch 36/100
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0046
# Epoch 37/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0056
# Epoch 38/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0039
# Epoch 39/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0051
# Epoch 40/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0046
# Epoch 41/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0047
# Epoch 42/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0041
# Epoch 43/100
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0035
# Epoch 44/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0041
# Epoch 45/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0032
# Epoch 46/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0042
# Epoch 47/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0037
# Epoch 48/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0052
# Epoch 49/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0025
# Epoch 50/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0033
# Epoch 51/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0044
# Epoch 52/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0034
# Epoch 53/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0031
# Epoch 54/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0029
# Epoch 55/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0039
# Epoch 56/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0028
# Epoch 57/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0039
# Epoch 58/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0033
# Epoch 59/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0026
# Epoch 60/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0034
# Epoch 61/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0024
# Epoch 62/100
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0033
# Epoch 63/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0029
# Epoch 64/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0028
# Epoch 65/100
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0025
# Epoch 66/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0025
# Epoch 67/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0031
# Epoch 68/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0027
# Epoch 69/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0026
# Epoch 70/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0026
# Epoch 71/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0023
# Epoch 72/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0025
# Epoch 73/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0027
# Epoch 74/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0020
# Epoch 75/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0024
# Epoch 76/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0023
# Epoch 77/100
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0026
# Epoch 78/100
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0021
# Epoch 79/100
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0021
# Epoch 80/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0026
# Epoch 81/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0018
# Epoch 82/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0023
# Epoch 83/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0022
# Epoch 84/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0021
# Epoch 85/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0025
# Epoch 86/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0020
# Epoch 87/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0020
# Epoch 88/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0021
# Epoch 89/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0022
# Epoch 90/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0014
# Epoch 91/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0024
# Epoch 92/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0016
# Epoch 93/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0019
# Epoch 94/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0018
# Epoch 95/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0022
# Epoch 96/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0015
# Epoch 97/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0015
# Epoch 98/100
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0016
# Epoch 99/100
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0019
# Epoch 100/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0018
# Epoch 1/50
# 19/19 [==============================] - 2s 81ms/step - loss: 0.1233
# Epoch 2/50
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0294
# Epoch 3/50
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0041
# Epoch 4/50
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0011
# Epoch 5/50
# 19/19 [==============================] - 1s 79ms/step - loss: 6.4090e-04
# Epoch 6/50
# 19/19 [==============================] - 2s 85ms/step - loss: 6.4179e-04
# Epoch 7/50
# 19/19 [==============================] - 2s 86ms/step - loss: 6.2489e-04
# Epoch 8/50
# 19/19 [==============================] - 2s 98ms/step - loss: 6.2174e-04
# Epoch 9/50
# 19/19 [==============================] - 2s 102ms/step - loss: 6.2413e-04
# Epoch 10/50
# 19/19 [==============================] - 2s 104ms/step - loss: 6.3444e-04
# Epoch 11/50
# 19/19 [==============================] - 2s 105ms/step - loss: 6.3208e-04
# Epoch 12/50
# 19/19 [==============================] - 2s 103ms/step - loss: 6.2404e-04
# Epoch 13/50
# 19/19 [==============================] - 2s 107ms/step - loss: 6.2469e-04
# Epoch 14/50
# 19/19 [==============================] - 2s 104ms/step - loss: 6.2385e-04
# Epoch 15/50
# 19/19 [==============================] - 2s 104ms/step - loss: 6.1913e-04
# Epoch 16/50
# 19/19 [==============================] - 3s 154ms/step - loss: 6.2526e-04
# Epoch 17/50
# 19/19 [==============================] - 3s 160ms/step - loss: 6.2011e-04
# Epoch 18/50
# 19/19 [==============================] - 3s 135ms/step - loss: 6.1954e-04
# Epoch 19/50
# 19/19 [==============================] - 2s 116ms/step - loss: 6.2286e-04
# Epoch 20/50
# 19/19 [==============================] - 2s 112ms/step - loss: 6.2746e-04
# Epoch 21/50
# 19/19 [==============================] - 2s 113ms/step - loss: 6.2656e-04
# Epoch 22/50
# 19/19 [==============================] - 2s 102ms/step - loss: 6.1594e-04
# Epoch 23/50
# 19/19 [==============================] - 2s 100ms/step - loss: 6.1504e-04
# Epoch 24/50
# 19/19 [==============================] - 2s 107ms/step - loss: 6.1773e-04
# Epoch 25/50
# 19/19 [==============================] - 2s 103ms/step - loss: 6.2352e-04
# Epoch 26/50
# 19/19 [==============================] - 2s 103ms/step - loss: 6.2527e-04
# Epoch 27/50
# 19/19 [==============================] - 2s 100ms/step - loss: 6.1418e-04
# Epoch 28/50
# 19/19 [==============================] - 2s 101ms/step - loss: 6.1580e-04
# Epoch 29/50
# 19/19 [==============================] - 2s 100ms/step - loss: 6.1786e-04
# Epoch 30/50
# 19/19 [==============================] - 2s 98ms/step - loss: 6.1760e-04
# Epoch 31/50
# 19/19 [==============================] - 2s 98ms/step - loss: 6.2135e-04
# Epoch 32/50
# 19/19 [==============================] - 2s 98ms/step - loss: 6.4080e-04
# Epoch 33/50
# 19/19 [==============================] - 2s 96ms/step - loss: 6.4135e-04
# Epoch 34/50
# 19/19 [==============================] - 2s 97ms/step - loss: 6.1802e-04
# Epoch 35/50
# 19/19 [==============================] - 2s 98ms/step - loss: 6.1093e-04
# Epoch 36/50
# 19/19 [==============================] - 2s 101ms/step - loss: 6.5326e-04
# Epoch 37/50
# 19/19 [==============================] - 2s 101ms/step - loss: 6.1776e-04
# Epoch 38/50
# 19/19 [==============================] - 2s 101ms/step - loss: 6.1101e-04
# Epoch 39/50
# 19/19 [==============================] - 2s 101ms/step - loss: 6.1027e-04
# Epoch 40/50
# 19/19 [==============================] - 2s 102ms/step - loss: 6.0996e-04
# Epoch 41/50
# 19/19 [==============================] - 2s 104ms/step - loss: 6.0755e-04
# Epoch 42/50
# 19/19 [==============================] - 2s 101ms/step - loss: 6.2426e-04
# Epoch 43/50
# 19/19 [==============================] - 2s 101ms/step - loss: 6.1591e-04
# Epoch 44/50
# 19/19 [==============================] - 2s 97ms/step - loss: 6.2329e-04
# Epoch 45/50
# 19/19 [==============================] - 2s 97ms/step - loss: 6.0799e-04
# Epoch 46/50
# 19/19 [==============================] - 2s 110ms/step - loss: 6.0821e-04
# Epoch 47/50
# 19/19 [==============================] - 2s 100ms/step - loss: 6.0998e-04
# Epoch 48/50
# 19/19 [==============================] - 2s 105ms/step - loss: 6.2184e-04
# Epoch 49/50
# 19/19 [==============================] - 2s 105ms/step - loss: 6.0632e-04
# Epoch 50/50
# 19/19 [==============================] - 2s 100ms/step - loss: 6.1696e-04
# Epoch 1/50
# 19/19 [==============================] - 2s 89ms/step - loss: 0.1068
# Epoch 2/50
# 19/19 [==============================] - 2s 89ms/step - loss: 0.0315
# Epoch 3/50
# 19/19 [==============================] - 2s 97ms/step - loss: 0.0087
# Epoch 4/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0051
# Epoch 5/50
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0043
# Epoch 6/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0043
# Epoch 7/50
# 19/19 [==============================] - 2s 112ms/step - loss: 0.0040
# Epoch 8/50
# 19/19 [==============================] - 5s 266ms/step - loss: 0.0038
# Epoch 9/50
# 19/19 [==============================] - 3s 152ms/step - loss: 0.0033
# Epoch 10/50
# 19/19 [==============================] - 3s 142ms/step - loss: 0.0034
# Epoch 11/50
# 19/19 [==============================] - 3s 153ms/step - loss: 0.0034
# Epoch 12/50
# 19/19 [==============================] - 3s 135ms/step - loss: 0.0031
# Epoch 13/50
# 19/19 [==============================] - 2s 128ms/step - loss: 0.0032
# Epoch 14/50
# 19/19 [==============================] - 2s 121ms/step - loss: 0.0030
# Epoch 15/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0029
# Epoch 16/50
# 19/19 [==============================] - 2s 112ms/step - loss: 0.0029
# Epoch 17/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0028
# Epoch 18/50
# 19/19 [==============================] - 2s 120ms/step - loss: 0.0026
# Epoch 19/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0027
# Epoch 20/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0025
# Epoch 21/50
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0026
# Epoch 22/50
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0027
# Epoch 23/50
# 19/19 [==============================] - 2s 113ms/step - loss: 0.0027
# Epoch 24/50
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0026
# Epoch 25/50
# 19/19 [==============================] - 2s 120ms/step - loss: 0.0024
# Epoch 26/50
# 19/19 [==============================] - 2s 112ms/step - loss: 0.0024
# Epoch 27/50
# 19/19 [==============================] - 2s 113ms/step - loss: 0.0024
# Epoch 28/50
# 19/19 [==============================] - 2s 113ms/step - loss: 0.0025
# Epoch 29/50
# 19/19 [==============================] - 2s 112ms/step - loss: 0.0025
# Epoch 30/50
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0023
# Epoch 31/50
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0024
# Epoch 32/50
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0022
# Epoch 33/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0023
# Epoch 34/50
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0022
# Epoch 35/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0023
# Epoch 36/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0024
# Epoch 37/50
# 19/19 [==============================] - 2s 113ms/step - loss: 0.0022
# Epoch 38/50
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0023
# Epoch 39/50
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0022
# Epoch 40/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0022
# Epoch 41/50
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0022
# Epoch 42/50
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0022
# Epoch 43/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0022
# Epoch 44/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0022
# Epoch 45/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0021
# Epoch 46/50
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0021
# Epoch 47/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0021
# Epoch 48/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0022
# Epoch 49/50
# 19/19 [==============================] - 2s 104ms/step - loss: 0.0020
# Epoch 50/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0021
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# We implemented deep learning models such as RNN model and GRU model for predicting stock prices. We further improved the performance of these models by varying some parameters such as adding layers, dropouts etc. Moreover, we also used facebook prophet model for predicting stock prices. we did a few runs to make the prophet model directly comparable to the recurrent models used above, but these models take a significant amount of time to run. As a result, the single layer RNN model(Green line from figure) is the best model when compared with all the models listed above.
